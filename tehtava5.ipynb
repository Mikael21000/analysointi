# %%
import pandas as pd

chipo = pd.read_csv("C:/Users/Mikael/Downloads/archive/ObesityDataSet_raw_and_data_sinthetic.csv")

# %%
chipo.head(10)
# Out:
#   Age,Gender,Height,Weight,CALC,FAVC,FCVC,NCP,SCC,SMOKE,CH2O,family_history_with_overweight,FAF,TUE,CAEC,MTRANS,NObeyesdad
# 0  21,Female,1.62,64,no,no,2,3,no,no,2,yes,0,1,So...
# 1  21,Female,1.52,56,Sometimes,no,3,3,yes,yes,3,y...
# 2  23,Male,1.8,77,Frequently,no,2,3,no,no,2,yes,2...
# 3  27,Male,1.8,87,Frequently,no,3,3,no,no,2,no,2,...
# 4  22,Male,1.78,89.8,Sometimes,no,2,1,no,no,2,no,...
# 5  29,Male,1.62,53,Sometimes,yes,2,3,no,no,2,no,0...
# 6  23,Female,1.5,55,Sometimes,yes,3,3,no,no,2,yes...
# 7  22,Male,1.64,53,Sometimes,no,2,3,no,no,2,no,3,...
# 8  24,Male,1.78,64,Frequently,yes,3,3,no,no,2,yes...
# 9  22,Male,1.72,68,no,yes,2,3,no,no,2,yes,1,1,Som...

# %%
# to display the first 10 rows of the Pandas DataFrame called chipo
chipo.shape[0]

# To provide a summary of information about the DataFrame chipo. It provides useful information such as data types and number of missing values.
chipo.info()

  # To return the the number of rows and columns of the DataFrame.
chipo.shape

# To return the number of columns in the dataset
chipo.shape[1]

# To Print the name of all the columns.
chipo.columns

# To return the index labels used in the chipo DataFrame
chipo.index

# To return a two-dimensional NumPy array that contains the data stored in the DataFrame.
chipo.values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 1 columns):
#  #   Column                                                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                                                    --------------  -----
#  0   Age,Gender,Height,Weight,CALC,FAVC,FCVC,NCP,SCC,SMOKE,CH2O,family_history_with_overweight,FAF,TUE,CAEC,MTRANS,NObeyesdad  2111 non-null   object
# dtypes: object(1)
# memory usage: 16.6+ KB
# array([['21,Female,1.62,64,no,no,2,3,no,no,2,yes,0,1,Sometimes,Public_Transportation,Normal_Weight'],
#        ['21,Female,1.52,56,Sometimes,no,3,3,yes,yes,3,yes,3,0,Sometimes,Public_Transportation,Normal_Weight'],
#        ['23,Male,1.8,77,Frequently,no,2,3,no,no,2,yes,2,1,Sometimes,Public_Transportation,Normal_Weight'],
#        ...,
#        ['22.524036,Female,1.752206,133.689352,Sometimes,yes,3,3,no,no,2.054193,yes,1.414209,0.646288,Sometimes,Public_Transportation,Obesity_Type_III'],
#        ['24.361936,Female,1.73945,133.346641,Sometimes,yes,3,3,no,no,2.852339,yes,1.139107,0.586035,Sometimes,Public_Transportation,Obesity_Type_III'],
#        ['23.664709,Female,1.738836,133.472641,Sometimes,yes,3,3,no,no,2.863513,yes,1.026452,0.714137,Sometimes,Public_Transportation,Obesity_Type_III']],
#       dtype=object)

# %%
# Get data types of multiple columns
column_data_types = chipo.dtypes
print(column_data_types)
# Out:
# Age,Gender,Height,Weight,CALC,FAVC,FCVC,NCP,SCC,SMOKE,CH2O,family_history_with_overweight,FAF,TUE,CAEC,MTRANS,NObeyesdad    object
# dtype: object

# %%
# Get data type of a single column
column_data_type = chipo['Age'].dtype
print(column_data_type)
# Out:
# float64

# %%
chipo.sort_values("Age")
# Out:
#             Age  Gender    Height     Weight        CALC FAVC  FCVC  NCP SCC  \
# 415   14.000000    Male  1.710000  72.000000          no  yes   3.0  3.0  no
# 116   15.000000  Female  1.650000  86.000000          no  yes   3.0  3.0  no
# 309   16.000000  Female  1.660000  58.000000          no   no   2.0  1.0  no
# 295   16.000000  Female  1.660000  58.000000          no   no   2.0  1.0  no
# 303   16.000000  Female  1.570000  49.000000   Sometimes  yes   2.0  4.0  no
# ...         ...     ...       ...        ...         ...  ...   ...  ...  ..
# 1158  55.022494    Male  1.673394  80.400306          no  yes   2.0  3.0  no
# 1088  55.137881    Male  1.657221  80.993213          no  yes   2.0  3.0  no
# 1013  55.246250    Male  1.769269  80.491339          no  yes   2.0  3.0  no
# 252   56.000000    Male  1.790000  90.000000  Frequently   no   2.0  3.0  no
# 133   61.000000  Female  1.650000  66.000000  Frequently  yes   3.0  3.0  no
#
#      SMOKE  CH2O family_history_with_overweight  FAF  TUE       CAEC  \
# 415     no   3.0                            yes  2.0  1.0  Sometimes
# 116     no   1.0                            yes  3.0  2.0  Sometimes
# 309     no   1.0                             no  0.0  1.0  Sometimes
# 295     no   1.0                             no  0.0  1.0  Sometimes
# 303     no   2.0                             no  0.0  1.0     Always
# ...    ...   ...                            ...  ...  ...        ...
# 1158    no   2.0                            yes  1.0  0.0  Sometimes
# 1088    no   2.0                            yes  1.0  0.0  Sometimes
# 1013    no   2.0                             no  1.0  0.0  Sometimes
# 252    yes   2.0                            yes  1.0  0.0  Sometimes
# 133     no   2.0                             no  1.0  1.0     Always
#
#                      MTRANS           NObeyesdad
# 415                 Walking        Normal_Weight
# 116                 Walking       Obesity_Type_I
# 309                 Walking        Normal_Weight
# 295                 Walking        Normal_Weight
# 303   Public_Transportation        Normal_Weight
# ...                     ...                  ...
# 1158             Automobile  Overweight_Level_II
# 1088             Automobile  Overweight_Level_II
# 1013             Automobile  Overweight_Level_II
# 252              Automobile  Overweight_Level_II
# 133   Public_Transportation        Normal_Weight
#
# [2111 rows x 17 columns]

# %%
chipo.sort_values("Age", ascending=False)
# Out:
#             Age  Gender    Height     Weight        CALC FAVC  FCVC  NCP SCC  \
# 133   61.000000  Female  1.650000  66.000000  Frequently  yes   3.0  3.0  no
# 252   56.000000    Male  1.790000  90.000000  Frequently   no   2.0  3.0  no
# 1013  55.246250    Male  1.769269  80.491339          no  yes   2.0  3.0  no
# 1088  55.137881    Male  1.657221  80.993213          no  yes   2.0  3.0  no
# 1158  55.022494    Male  1.673394  80.400306          no  yes   2.0  3.0  no
# ...         ...     ...       ...        ...         ...  ...   ...  ...  ..
# 312   16.000000  Female  1.600000  57.000000          no  yes   3.0  3.0  no
# 295   16.000000  Female  1.660000  58.000000          no   no   2.0  1.0  no
# 290   16.000000    Male  1.820000  71.000000   Sometimes  yes   2.0  3.0  no
# 116   15.000000  Female  1.650000  86.000000          no  yes   3.0  3.0  no
# 415   14.000000    Male  1.710000  72.000000          no  yes   3.0  3.0  no
#
#      SMOKE  CH2O family_history_with_overweight  FAF  TUE        CAEC  \
# 133     no   2.0                             no  1.0  1.0      Always
# 252    yes   2.0                            yes  1.0  0.0   Sometimes
# 1013    no   2.0                             no  1.0  0.0   Sometimes
# 1088    no   2.0                            yes  1.0  0.0   Sometimes
# 1158    no   2.0                            yes  1.0  0.0   Sometimes
# ...    ...   ...                            ...  ...  ...         ...
# 312     no   1.0                             no  3.0  0.0   Sometimes
# 295     no   1.0                             no  0.0  1.0   Sometimes
# 290     no   2.0                            yes  2.0  1.0  Frequently
# 116     no   1.0                            yes  3.0  2.0   Sometimes
# 415     no   3.0                            yes  2.0  1.0   Sometimes
#
#                      MTRANS           NObeyesdad
# 133   Public_Transportation        Normal_Weight
# 252              Automobile  Overweight_Level_II
# 1013             Automobile  Overweight_Level_II
# 1088             Automobile  Overweight_Level_II
# 1158             Automobile  Overweight_Level_II
# ...                     ...                  ...
# 312   Public_Transportation        Normal_Weight
# 295                 Walking        Normal_Weight
# 290   Public_Transportation        Normal_Weight
# 116                 Walking       Obesity_Type_I
# 415                 Walking        Normal_Weight
#
# [2111 rows x 17 columns]

# %%
chipo.sort_values(["Age", "Gender"], ascending=[True, False])
# Out:
#             Age  Gender    Height     Weight        CALC FAVC  FCVC  NCP SCC  \
# 415   14.000000    Male  1.710000  72.000000          no  yes   3.0  3.0  no
# 116   15.000000  Female  1.650000  86.000000          no  yes   3.0  3.0  no
# 276   16.000000    Male  1.670000  50.000000          no  yes   2.0  1.0  no
# 290   16.000000    Male  1.820000  71.000000   Sometimes  yes   2.0  3.0  no
# 302   16.000000    Male  1.840000  45.000000   Sometimes  yes   3.0  3.0  no
# ...         ...     ...       ...        ...         ...  ...   ...  ...  ..
# 1158  55.022494    Male  1.673394  80.400306          no  yes   2.0  3.0  no
# 1088  55.137881    Male  1.657221  80.993213          no  yes   2.0  3.0  no
# 1013  55.246250    Male  1.769269  80.491339          no  yes   2.0  3.0  no
# 252   56.000000    Male  1.790000  90.000000  Frequently   no   2.0  3.0  no
# 133   61.000000  Female  1.650000  66.000000  Frequently  yes   3.0  3.0  no
#
#      SMOKE  CH2O family_history_with_overweight  FAF  TUE        CAEC  \
# 415     no   3.0                            yes  2.0  1.0   Sometimes
# 116     no   1.0                            yes  3.0  2.0   Sometimes
# 276     no   3.0                            yes  1.0  0.0  Frequently
# 290     no   2.0                            yes  2.0  1.0  Frequently
# 302     no   3.0                            yes  3.0  2.0      Always
# ...    ...   ...                            ...  ...  ...         ...
# 1158    no   2.0                            yes  1.0  0.0   Sometimes
# 1088    no   2.0                            yes  1.0  0.0   Sometimes
# 1013    no   2.0                             no  1.0  0.0   Sometimes
# 252    yes   2.0                            yes  1.0  0.0   Sometimes
# 133     no   2.0                             no  1.0  1.0      Always
#
#                      MTRANS           NObeyesdad
# 415                 Walking        Normal_Weight
# 116                 Walking       Obesity_Type_I
# 276   Public_Transportation  Insufficient_Weight
# 290   Public_Transportation        Normal_Weight
# 302                 Walking  Insufficient_Weight
# ...                     ...                  ...
# 1158             Automobile  Overweight_Level_II
# 1088             Automobile  Overweight_Level_II
# 1013             Automobile  Overweight_Level_II
# 252              Automobile  Overweight_Level_II
# 133   Public_Transportation        Normal_Weight
#
# [2111 rows x 17 columns]

# %%
subset_chipo = chipo["Weight"]
print(subset_chipo)

# selecting multiple columns
subset_chipo1 = chipo[["Age", "Weight", "Gender"]]
print(subset_chipo1)
# Out:
# 0        64.000000
# 1        56.000000
# 2        77.000000
# 3        87.000000
# 4        89.800000
#            ...
# 2106    131.408528
# 2107    133.742943
# 2108    133.689352
# 2109    133.346641
# 2110    133.472641
# Name: Weight, Length: 2111, dtype: float64
#             Age      Weight  Gender
# 0     21.000000   64.000000  Female
# 1     21.000000   56.000000  Female
# 2     23.000000   77.000000    Male
# 3     27.000000   87.000000    Male
# 4     22.000000   89.800000    Male
# ...         ...         ...     ...
# 2106  20.976842  131.408528  Female
# 2107  21.982942  133.742943  Female
# 2108  22.524036  133.689352  Female
# 2109  24.361936  133.346641  Female
# 2110  23.664709  133.472641  Female
#
# [2111 rows x 3 columns]

# %%
subset_df = chipo[chipo['Age'] > 40]
print(subset_df)
# Out:
#             Age  Gender    Height      Weight        CALC FAVC      FCVC  \
# 13    41.000000    Male  1.800000   99.000000  Frequently  yes  2.000000
# 21    52.000000  Female  1.690000   87.000000          no  yes  3.000000
# 92    55.000000    Male  1.780000   84.000000  Frequently   no  3.000000
# 133   61.000000  Female  1.650000   66.000000  Frequently  yes  3.000000
# 137   44.000000    Male  1.600000   80.000000          no   no  2.000000
# 161   55.000000    Male  1.650000   80.000000          no  yes  2.000000
# 169   45.000000  Female  1.630000   77.000000          no  yes  2.000000
# 197   41.000000    Male  1.750000  118.000000   Sometimes  yes  2.000000
# 201   41.000000  Female  1.540000   80.000000   Sometimes  yes  2.000000
# 232   51.000000  Female  1.590000   50.000000          no   no  3.000000
# 252   56.000000    Male  1.790000   90.000000  Frequently   no  2.000000
# 358   41.000000    Male  1.750000  110.000000  Frequently   no  2.000000
# 375   41.000000    Male  1.800000   92.000000   Sometimes  yes  2.000000
# 492   45.000000    Male  1.700000   86.000000          no  yes  3.000000
# 751   41.823567  Female  1.721854   82.919584   Sometimes  yes  2.816460
# 813   42.244750  Female  1.768231   75.629310   Sometimes  yes  3.000000
# 1013  55.246250    Male  1.769269   80.491339          no  yes  2.000000
# 1017  42.189023  Female  1.647768   79.165306          no  yes  2.000000
# 1034  50.832559    Male  1.745528   82.130728          no  yes  2.000000
# 1062  43.238402  Female  1.733875   86.945380          no  yes  2.353603
# 1063  45.000000  Female  1.675953   79.668320          no  yes  2.598051
# 1088  55.137881    Male  1.657221   80.993213          no  yes  2.000000
# 1101  46.491859    Male  1.718097   88.600878          no  yes  2.129969
# 1158  55.022494    Male  1.673394   80.400306          no  yes  2.000000
# 1162  41.743333  Female  1.678610   79.849252          no  yes  2.733129
# 1179  47.706100    Male  1.743935   84.729197          no  yes  2.535315
# 1208  45.821267  Female  1.687326   80.413997          no  yes  2.076689
# 1215  43.604901  Female  1.569234   81.827288          no  yes  2.909853
# 1216  42.316070  Female  1.583943   81.936398          no  yes  2.490507
# 1229  40.821515  Female  1.553026   77.745180   Sometimes  yes  2.000000
# 1234  40.317787    Male  1.786318   98.447311   Sometimes  yes  2.000000
# 1241  40.951591  Female  1.542122   80.000000   Sometimes  yes  2.000000
# 1267  43.510672  Female  1.587546   76.126112   Sometimes  yes  2.000000
# 1285  42.337283  Female  1.646390   86.639861          no  yes  2.816460
# 1286  47.283374  Female  1.643786   81.978743          no  yes  2.037585
# 1305  43.591999  Female  1.595165   77.354744          no  yes  2.000000
# 1306  40.993179  Female  1.567756   79.493626          no  yes  2.000000
# 1325  41.403862  Female  1.567973   81.056851   Sometimes  yes  2.152264
# 1326  40.702771  Female  1.548403   80.000000   Sometimes  yes  2.000000
# 1385  42.586285  Female  1.571417   81.918809          no  yes  2.522183
# 1386  43.719395  Female  1.584322   80.986496          no  yes  2.186322
# 1387  43.376340  Female  1.582523   81.919454          no  yes  2.766320
# 1413  40.466313  Female  1.559005   77.601483   Sometimes  yes  2.000000
# 1438  40.789529  Female  1.549748   80.000000   Sometimes  yes  2.000000
# 1439  40.654155  Female  1.529060   79.760922   Sometimes  yes  2.000000
# 1489  41.318302  Female  1.544937   77.053948   Sometimes  yes  2.000000
# 1490  43.726081  Female  1.592316   77.001030   Sometimes  yes  2.000000
# 1529  41.000000    Male  1.750000  116.594351   Sometimes  yes  2.000000
# 1551  40.500210    Male  1.748103  108.308112          no  yes  2.317459
# 1562  40.794057    Male  1.735851  109.889334          no  yes  2.305349
# 1617  40.973007    Male  1.749405  109.908779          no  yes  2.176317
# 1618  41.000000    Male  1.750000  115.806977          no  yes  2.000000
# 1627  40.366238    Male  1.722396  109.349025          no  yes  2.281963
# 1655  40.106145    Male  1.760175  117.651046   Sometimes  yes  2.032883
# 1656  40.174191    Male  1.763029  116.974504   Sometimes  yes  2.046651
# 1721  40.564513    Male  1.748015  109.758736          no  yes  2.310751
# 1722  40.501722    Male  1.744974  111.169678          no  yes  2.294259
#
#            NCP  SCC SMOKE      CH2O family_history_with_overweight       FAF  \
# 13    3.000000   no    no  2.000000                             no  2.000000
# 21    1.000000   no   yes  2.000000                            yes  0.000000
# 92    4.000000  yes    no  3.000000                            yes  3.000000
# 133   3.000000   no    no  2.000000                             no  1.000000
# 137   3.000000   no   yes  3.000000                            yes  0.000000
# 161   3.000000   no    no  2.000000                             no  1.000000
# 169   3.000000   no    no  1.000000                            yes  0.000000
# 197   3.000000   no    no  2.000000                            yes  0.000000
# 201   3.000000   no    no  1.000000                            yes  0.000000
# 232   3.000000  yes   yes  3.000000                            yes  2.000000
# 252   3.000000   no   yes  2.000000                            yes  1.000000
# 358   1.000000   no    no  1.000000                            yes  1.000000
# 375   1.000000   no    no  3.000000                            yes  1.000000
# 492   3.000000   no    no  1.000000                             no  0.000000
# 751   3.363130   no    no  2.722063                             no  3.000000
# 813   2.951837   no    no  2.112032                            yes  0.378683
# 1013  3.000000   no    no  2.000000                             no  1.000000
# 1017  3.000000   no    no  1.000000                            yes  0.000000
# 1034  3.000000   no    no  1.774778                            yes  0.943266
# 1062  2.337035   no    no  1.830614                            yes  0.706287
# 1063  3.000000   no    no  1.000000                            yes  0.000000
# 1088  3.000000   no    no  2.000000                            yes  1.000000
# 1101  3.000000   no    no  1.568035                            yes  0.870127
# 1158  3.000000   no    no  2.000000                            yes  1.000000
# 1162  3.000000   no    no  1.302594                            yes  0.000000
# 1179  3.000000   no    no  1.146595                            yes  0.313810
# 1208  3.000000   no    no  1.026729                            yes  0.647798
# 1215  1.000000   no    no  2.000000                            yes  1.308852
# 1216  2.974204   no    no  1.846754                            yes  0.000000
# 1229  3.000000   no    no  1.406115                            yes  0.000000
# 1234  3.000000   no    no  2.680292                            yes  1.549693
# 1241  1.105617   no    no  1.372811                            yes  1.629432
# 1267  3.000000   no    no  2.091934                            yes  0.000000
# 1285  2.273740   no    no  1.722063                            yes  0.000000
# 1286  1.418985   no    no  1.827351                            yes  0.000000
# 1305  3.000000   no    no  2.117346                            yes  0.000000
# 1306  3.000000   no    no  2.952506                            yes  0.000000
# 1325  2.977999   no    no  1.513199                            yes  0.000000
# 1326  3.000000   no    no  1.326165                            yes  0.000000
# 1385  1.326982   no    no  1.872673                            yes  1.048507
# 1386  2.900915   no    no  2.471033                            yes  0.256113
# 1387  1.317884   no    no  1.889341                            yes  0.990642
# 1413  3.000000   no    no  1.572371                            yes  0.000000
# 1438  1.099151   no    no  1.687611                            yes  1.874662
# 1439  3.000000   no    no  1.000000                            yes  0.000000
# 1489  3.000000   no    no  2.090413                            yes  0.000000
# 1490  3.000000   no    no  2.806922                            yes  0.000000
# 1529  2.831771   no    no  1.725226                            yes  0.356288
# 1551  3.734323   no    no  1.000000                            yes  1.628637
# 1562  3.169089   no    no  1.021610                            yes  0.908981
# 1617  2.986637   no    no  1.015672                            yes  0.941410
# 1618  2.701521   no    no  1.142644                            yes  0.514225
# 1627  3.770379   no    no  1.000000                            yes  1.330519
# 1655  2.976211   no    no  1.726109                            yes  0.477855
# 1656  2.842035   no    no  1.732072                            yes  0.584272
# 1721  3.220181   no    no  1.006643                            yes  1.158040
# 1722  2.850948   no    no  1.870290                            yes  0.917014
#
#            TUE        CAEC                 MTRANS           NObeyesdad
# 13    1.000000   Sometimes             Automobile       Obesity_Type_I
# 21    0.000000   Sometimes             Automobile       Obesity_Type_I
# 92    0.000000  Frequently                Walking   Overweight_Level_I
# 133   1.000000      Always  Public_Transportation        Normal_Weight
# 137   0.000000   Sometimes              Motorbike       Obesity_Type_I
# 161   0.000000   Sometimes             Automobile  Overweight_Level_II
# 169   0.000000  Frequently             Automobile  Overweight_Level_II
# 197   0.000000   Sometimes                   Bike      Obesity_Type_II
# 201   0.000000      Always             Automobile       Obesity_Type_I
# 232   0.000000   Sometimes  Public_Transportation        Normal_Weight
# 252   0.000000   Sometimes             Automobile  Overweight_Level_II
# 358   0.000000   Sometimes             Automobile      Obesity_Type_II
# 375   0.000000  Frequently             Automobile  Overweight_Level_II
# 492   0.000000  Frequently             Automobile  Overweight_Level_II
# 751   0.265790   Sometimes             Automobile   Overweight_Level_I
# 813   0.000000   Sometimes             Automobile   Overweight_Level_I
# 1013  0.000000   Sometimes             Automobile  Overweight_Level_II
# 1017  1.481890   Sometimes             Automobile  Overweight_Level_II
# 1034  0.000000   Sometimes             Automobile  Overweight_Level_II
# 1062  0.000000   Sometimes             Automobile  Overweight_Level_II
# 1063  0.000000   Sometimes             Automobile  Overweight_Level_II
# 1088  0.000000   Sometimes             Automobile  Overweight_Level_II
# 1101  0.000000   Sometimes             Automobile  Overweight_Level_II
# 1158  0.000000   Sometimes             Automobile  Overweight_Level_II
# 1162  1.103349   Sometimes             Automobile  Overweight_Level_II
# 1179  0.000000   Sometimes             Automobile  Overweight_Level_II
# 1208  0.000000   Sometimes             Automobile  Overweight_Level_II
# 1215  0.000000   Sometimes             Automobile       Obesity_Type_I
# 1216  0.000000   Sometimes             Automobile       Obesity_Type_I
# 1229  0.000000   Sometimes             Automobile       Obesity_Type_I
# 1234  0.522259   Sometimes             Automobile       Obesity_Type_I
# 1241  0.000000   Sometimes             Automobile       Obesity_Type_I
# 1267  0.000000   Sometimes             Automobile       Obesity_Type_I
# 1285  0.000000   Sometimes             Automobile       Obesity_Type_I
# 1286  0.000000   Sometimes             Automobile       Obesity_Type_I
# 1305  0.000000   Sometimes             Automobile       Obesity_Type_I
# 1306  0.000000   Sometimes             Automobile       Obesity_Type_I
# 1325  0.000000   Sometimes             Automobile       Obesity_Type_I
# 1326  0.000000   Sometimes             Automobile       Obesity_Type_I
# 1385  0.000000   Sometimes             Automobile       Obesity_Type_I
# 1386  0.000000   Sometimes             Automobile       Obesity_Type_I
# 1387  0.000000   Sometimes             Automobile       Obesity_Type_I
# 1413  0.000000   Sometimes             Automobile       Obesity_Type_I
# 1438  0.000000   Sometimes             Automobile       Obesity_Type_I
# 1439  0.000000   Sometimes             Automobile       Obesity_Type_I
# 1489  0.000000   Sometimes             Automobile       Obesity_Type_I
# 1490  0.000000   Sometimes             Automobile       Obesity_Type_I
# 1529  0.000000   Sometimes             Automobile      Obesity_Type_II
# 1551  0.000000   Sometimes             Automobile      Obesity_Type_II
# 1562  0.000000   Sometimes             Automobile      Obesity_Type_II
# 1617  0.000000   Sometimes             Automobile      Obesity_Type_II
# 1618  0.000000   Sometimes             Automobile      Obesity_Type_II
# 1627  0.000000   Sometimes             Automobile      Obesity_Type_II
# 1655  0.000000   Sometimes             Automobile      Obesity_Type_II
# 1656  0.000000   Sometimes             Automobile      Obesity_Type_II
# 1721  0.000000   Sometimes             Automobile      Obesity_Type_II
# 1722  0.000000   Sometimes             Automobile      Obesity_Type_II
# Empty DataFrame
# Columns: [Age, Gender, Height, Weight, CALC, FAVC, FCVC, NCP, SCC, SMOKE, CH2O, family_history_with_overweight, FAF, TUE, CAEC, MTRANS, NObeyesdad]
# Index: []

# %%
# subsetting based on text data
subset_df = chipo[chipo['Gender'] == "Female"]
print(subset_df)
# Out:
#             Age  Gender    Height      Weight       CALC FAVC  FCVC  NCP  SCC  \
# 0     21.000000  Female  1.620000   64.000000         no   no   2.0  3.0   no
# 1     21.000000  Female  1.520000   56.000000  Sometimes   no   3.0  3.0  yes
# 6     23.000000  Female  1.500000   55.000000  Sometimes  yes   3.0  3.0   no
# 11    21.000000  Female  1.720000   80.000000  Sometimes  yes   2.0  3.0  yes
# 15    22.000000  Female  1.700000   66.000000  Sometimes   no   3.0  3.0  yes
# ...         ...     ...       ...         ...        ...  ...   ...  ...  ...
# 2106  20.976842  Female  1.710730  131.408528  Sometimes  yes   3.0  3.0   no
# 2107  21.982942  Female  1.748584  133.742943  Sometimes  yes   3.0  3.0   no
# 2108  22.524036  Female  1.752206  133.689352  Sometimes  yes   3.0  3.0   no
# 2109  24.361936  Female  1.739450  133.346641  Sometimes  yes   3.0  3.0   no
# 2110  23.664709  Female  1.738836  133.472641  Sometimes  yes   3.0  3.0   no
#
#      SMOKE      CH2O family_history_with_overweight       FAF       TUE  \
# 0       no  2.000000                            yes  0.000000  1.000000
# 1      yes  3.000000                            yes  3.000000  0.000000
# 6       no  2.000000                            yes  1.000000  0.000000
# 11      no  2.000000                            yes  2.000000  1.000000
# 15      no  2.000000                            yes  2.000000  1.000000
# ...    ...       ...                            ...       ...       ...
# 2106    no  1.728139                            yes  1.676269  0.906247
# 2107    no  2.005130                            yes  1.341390  0.599270
# 2108    no  2.054193                            yes  1.414209  0.646288
# 2109    no  2.852339                            yes  1.139107  0.586035
# 2110    no  2.863513                            yes  1.026452  0.714137
#
#             CAEC                 MTRANS           NObeyesdad
# 0      Sometimes  Public_Transportation        Normal_Weight
# 1      Sometimes  Public_Transportation        Normal_Weight
# 6      Sometimes              Motorbike        Normal_Weight
# 11    Frequently  Public_Transportation  Overweight_Level_II
# 15        Always  Public_Transportation        Normal_Weight
# ...          ...                    ...                  ...
# 2106   Sometimes  Public_Transportation     Obesity_Type_III
# 2107   Sometimes  Public_Transportation     Obesity_Type_III
# 2108   Sometimes  Public_Transportation     Obesity_Type_III
# 2109   Sometimes  Public_Transportation     Obesity_Type_III
# 2110   Sometimes  Public_Transportation     Obesity_Type_III
#
# [1043 rows x 17 columns]

# %%
subset_df1 = chipo['Age'] > 30
subset_df2 = chipo['Gender'] == "Male"
subset_df3 = chipo[subset_df1 & subset_df2]
subset_df3.head()
# Out:
#       Age Gender  Height  Weight        CALC FAVC  FCVC  NCP  SCC SMOKE  CH2O  \
# 13   41.0   Male    1.80    99.0  Frequently  yes   2.0  3.0   no    no   2.0
# 33   39.0   Male    1.79    90.0   Sometimes   no   2.0  1.0   no    no   2.0
# 92   55.0   Male    1.78    84.0  Frequently   no   3.0  4.0  yes    no   3.0
# 137  44.0   Male    1.60    80.0          no   no   2.0  3.0   no   yes   3.0
# 138  31.0   Male    1.76    75.0          no   no   3.0  3.0  yes    no   3.0
#
#     family_history_with_overweight  FAF  TUE        CAEC  \
# 13                              no  2.0  1.0   Sometimes
# 33                              no  0.0  0.0   Sometimes
# 92                             yes  3.0  0.0  Frequently
# 137                            yes  0.0  0.0   Sometimes
# 138                            yes  3.0  0.0      Always
#
#                     MTRANS           NObeyesdad
# 13              Automobile       Obesity_Type_I
# 33   Public_Transportation  Overweight_Level_II
# 92                 Walking   Overweight_Level_I
# 137              Motorbike       Obesity_Type_I
# 138                   Bike        Normal_Weight

# %%
print(chipo['Height'].dtype)
# Out:
# float64

# %%
chipo['total'] = chipo['Height'] * chipo['Weight']

chipo.head(10)
# Out:
#     Age  Gender  Height  Weight        CALC FAVC  FCVC  NCP  SCC SMOKE  CH2O  \
# 0  21.0  Female    1.62    64.0          no   no   2.0  3.0   no    no   2.0
# 1  21.0  Female    1.52    56.0   Sometimes   no   3.0  3.0  yes   yes   3.0
# 2  23.0    Male    1.80    77.0  Frequently   no   2.0  3.0   no    no   2.0
# 3  27.0    Male    1.80    87.0  Frequently   no   3.0  3.0   no    no   2.0
# 4  22.0    Male    1.78    89.8   Sometimes   no   2.0  1.0   no    no   2.0
# 5  29.0    Male    1.62    53.0   Sometimes  yes   2.0  3.0   no    no   2.0
# 6  23.0  Female    1.50    55.0   Sometimes  yes   3.0  3.0   no    no   2.0
# 7  22.0    Male    1.64    53.0   Sometimes   no   2.0  3.0   no    no   2.0
# 8  24.0    Male    1.78    64.0  Frequently  yes   3.0  3.0   no    no   2.0
# 9  22.0    Male    1.72    68.0          no  yes   2.0  3.0   no    no   2.0
#
#   family_history_with_overweight  FAF  TUE       CAEC                 MTRANS  \
# 0                            yes  0.0  1.0  Sometimes  Public_Transportation
# 1                            yes  3.0  0.0  Sometimes  Public_Transportation
# 2                            yes  2.0  1.0  Sometimes  Public_Transportation
# 3                             no  2.0  0.0  Sometimes                Walking
# 4                             no  0.0  0.0  Sometimes  Public_Transportation
# 5                             no  0.0  0.0  Sometimes             Automobile
# 6                            yes  1.0  0.0  Sometimes              Motorbike
# 7                             no  3.0  0.0  Sometimes  Public_Transportation
# 8                            yes  1.0  1.0  Sometimes  Public_Transportation
# 9                            yes  1.0  1.0  Sometimes  Public_Transportation
#
#             NObeyesdad    total
# 0        Normal_Weight  103.680
# 1        Normal_Weight   85.120
# 2        Normal_Weight  138.600
# 3   Overweight_Level_I  156.600
# 4  Overweight_Level_II  159.844
# 5        Normal_Weight   85.860
# 6        Normal_Weight   82.500
# 7        Normal_Weight   86.920
# 8        Normal_Weight  113.920
# 9        Normal_Weight  116.960

# %%
# first lets create a function to define the price ranges
def categorize_age(Age):
    if Age < 5:
        return 'Young'
    elif Age < 40:
        return 'Adult'
    else:
        return 'Old'
# We can use the .apply() method to create a new column 'price_group' based on the 'item_price' column.
chipo['age_group'] = chipo['Age'].apply(categorize_age)
chipo.head(20)
# Out:
#      Age  Gender  Height  Weight        CALC FAVC  FCVC  NCP  SCC SMOKE  CH2O  \
# 0   21.0  Female    1.62    64.0          no   no   2.0  3.0   no    no   2.0
# 1   21.0  Female    1.52    56.0   Sometimes   no   3.0  3.0  yes   yes   3.0
# 2   23.0    Male    1.80    77.0  Frequently   no   2.0  3.0   no    no   2.0
# 3   27.0    Male    1.80    87.0  Frequently   no   3.0  3.0   no    no   2.0
# 4   22.0    Male    1.78    89.8   Sometimes   no   2.0  1.0   no    no   2.0
# 5   29.0    Male    1.62    53.0   Sometimes  yes   2.0  3.0   no    no   2.0
# 6   23.0  Female    1.50    55.0   Sometimes  yes   3.0  3.0   no    no   2.0
# 7   22.0    Male    1.64    53.0   Sometimes   no   2.0  3.0   no    no   2.0
# 8   24.0    Male    1.78    64.0  Frequently  yes   3.0  3.0   no    no   2.0
# 9   22.0    Male    1.72    68.0          no  yes   2.0  3.0   no    no   2.0
# 10  26.0    Male    1.85   105.0   Sometimes  yes   3.0  3.0   no    no   3.0
# 11  21.0  Female    1.72    80.0   Sometimes  yes   2.0  3.0  yes    no   2.0
# 12  22.0    Male    1.65    56.0   Sometimes   no   3.0  3.0   no    no   3.0
# 13  41.0    Male    1.80    99.0  Frequently  yes   2.0  3.0   no    no   2.0
# 14  23.0    Male    1.77    60.0   Sometimes  yes   3.0  1.0   no    no   1.0
# 15  22.0  Female    1.70    66.0   Sometimes   no   3.0  3.0  yes    no   2.0
# 16  27.0    Male    1.93   102.0   Sometimes  yes   2.0  1.0   no    no   1.0
# 17  29.0  Female    1.53    78.0          no  yes   2.0  1.0   no    no   2.0
# 18  30.0  Female    1.71    82.0          no  yes   3.0  4.0   no   yes   1.0
# 19  23.0  Female    1.65    70.0   Sometimes   no   2.0  1.0   no    no   2.0
#
#    family_history_with_overweight  FAF  TUE        CAEC  \
# 0                             yes  0.0  1.0   Sometimes
# 1                             yes  3.0  0.0   Sometimes
# 2                             yes  2.0  1.0   Sometimes
# 3                              no  2.0  0.0   Sometimes
# 4                              no  0.0  0.0   Sometimes
# 5                              no  0.0  0.0   Sometimes
# 6                             yes  1.0  0.0   Sometimes
# 7                              no  3.0  0.0   Sometimes
# 8                             yes  1.0  1.0   Sometimes
# 9                             yes  1.0  1.0   Sometimes
# 10                            yes  2.0  2.0  Frequently
# 11                            yes  2.0  1.0  Frequently
# 12                             no  2.0  0.0   Sometimes
# 13                             no  2.0  1.0   Sometimes
# 14                            yes  1.0  1.0   Sometimes
# 15                            yes  2.0  1.0      Always
# 16                            yes  1.0  0.0   Sometimes
# 17                             no  0.0  0.0   Sometimes
# 18                            yes  0.0  0.0  Frequently
# 19                            yes  0.0  0.0   Sometimes
#
#                    MTRANS           NObeyesdad    total age_group
# 0   Public_Transportation        Normal_Weight  103.680     Adult
# 1   Public_Transportation        Normal_Weight   85.120     Adult
# 2   Public_Transportation        Normal_Weight  138.600     Adult
# 3                 Walking   Overweight_Level_I  156.600     Adult
# 4   Public_Transportation  Overweight_Level_II  159.844     Adult
# 5              Automobile        Normal_Weight   85.860     Adult
# 6               Motorbike        Normal_Weight   82.500     Adult
# 7   Public_Transportation        Normal_Weight   86.920     Adult
# 8   Public_Transportation        Normal_Weight  113.920     Adult
# 9   Public_Transportation        Normal_Weight  116.960     Adult
# 10  Public_Transportation       Obesity_Type_I  194.250     Adult
# 11  Public_Transportation  Overweight_Level_II  137.600     Adult
# 12  Public_Transportation        Normal_Weight   92.400     Adult
# 13             Automobile       Obesity_Type_I  178.200       Old
# 14  Public_Transportation        Normal_Weight  106.200     Adult
# 15  Public_Transportation        Normal_Weight  112.200     Adult
# 16  Public_Transportation  Overweight_Level_II  196.860     Adult
# 17             Automobile       Obesity_Type_I  119.340     Adult
# 18             Automobile  Overweight_Level_II  140.220     Adult
# 19  Public_Transportation   Overweight_Level_I  115.500     Adult
